# %% [markdown]
# ## Shah Faisal Khan 21110156 CSE

# %% [markdown]
# ### Q1 Number of multiplications and additions required for a matrix multiplication of [A]n X k and [B]k X m

# %% [markdown]
# Number of additions required are n* m* (k-1) and number of multiplications required are n* m* k.
# The number of elements in the resultant matrix are n* m, therefore the operations are a multiple of n* m.
# For every element in the resultant matrix, the operations are done between k pairs of numbers from the two matrices, therefore k pairs are multiplied together. These k pairs are then added together requiring k-1 addition operations.

# %% [markdown]
# ### Q2 Python code and numpy to multiply matrices

# %%
#Python code for matrix multiplication
def matrix_multiply(matrix1, matrix2):
    if len(matrix1[0]) != len(matrix2):
        raise ValueError("not possible")
    result = [[0 for _ in range(len(matrix2[0]))] for _ in range(len(matrix1))]
    for i in range(len(matrix1)):
        for j in range(len(matrix2[0])):
            for k in range(len(matrix2)):
                result[i][j] += matrix1[i][k] * matrix2[k][j]
    return result

# %%
#Using numpy for matrix multiplication
import numpy as np

def matrix_multiply_numpy(matrix1, matrix2):
    try:
        result = np.dot(matrix1, matrix2)
        return result
    except ValueError:
        print("not possible")

# %%
matrix_a =([[1, 2, 3],
           [4, 5, 6],
           [4, 5, 6],
           [4, 5, 6],
           [4, 5, 6],
           [4, 5, 6]])

matrix_b = ([[7, 8,10,11,12,13,14],
            [9, 10,5,6,7,8,1],
            [11, 12,4,7,2,6,2]])

# %time matrix_multiply_numpy(matrix_a, matrix_b)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# array([[ 58,  64,  32,  44,  32,  47,  22],
#        [139, 154,  89, 116,  95, 128,  73],
#        [139, 154,  89, 116,  95, 128,  73],
#        [139, 154,  89, 116,  95, 128,  73],
#        [139, 154,  89, 116,  95, 128,  73],
#        [139, 154,  89, 116,  95, 128,  73]])

# %%
# %time matrix_multiply(matrix_a, matrix_b)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# [[58, 64, 32, 44, 32, 47, 22],
#  [139, 154, 89, 116, 95, 128, 73],
#  [139, 154, 89, 116, 95, 128, 73],
#  [139, 154, 89, 116, 95, 128, 73],
#  [139, 154, 89, 116, 95, 128, 73],
#  [139, 154, 89, 116, 95, 128, 73]]

# %% [markdown]
# The recorder cpu times and wall times are similar.

# %% [markdown]
# ### Q3 Time complexity of finding median

# %% [markdown]
# Time complexity required for finding median using largest element each time requires a O(n*n/2) which is O(n^2). This is because n/2 passes are required for finding the median from n elements array. Also a space complexity of O(n) is required to store the largest elements found till the median is found.

# %% [markdown]
# ##### Better method

# %%
# Passing method
def find_median_passing(arr):
    n = len(arr)
    largest_elements = set()
    
    for _ in range(n // 2):
        maxi = float('-inf')
        for num in arr:
            if num > maxi and num not in largest_elements:
                maxi = num
        
        if maxi != float('-inf'):
            largest_elements.add(maxi)

    if n % 2 == 1:
        return min(largest_elements)
    else:
        return (min(largest_elements) + max(largest_elements)) / 2

# %% [markdown]
# A better approch can be sorting the array requiring a time complexity of O(n logn) and then picking up the middle element or the avarage of the middle elements if two. If a copy of the array is created a space complexity of O(n) is required.

# %%
# Sort and find median
def find_median_sort(arr):
    sorted_arr = sorted(arr)
    n = len(sorted_arr)
    if n % 2 == 1:
        return sorted_arr[n // 2]
    else:
        mid1 = n // 2 - 1
        mid2 = n // 2
        return (sorted_arr[mid1] + sorted_arr[mid2]) / 2

# %%
arr = [3,4,5,3,5,1,2,5,3535,34524,23,222,42,1,4,2,1,5,46,9,124,56,6674,2,122,5,4,1,35,34]

# %%
# %time find_median_passing(arr)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 17264.0

# %%
# %time find_median_sort(arr)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 5.0

# %%
# %time np.median(arr)
# Out:
# CPU times: total: 0 ns
# Wall time: 298 µs
# 5.0

# %% [markdown]
# ### Q4 Gradient of funtion (x^2)y + (y^3)sin(x)

# %% [markdown]
# Differentiating function with respect to x gives:  (2*x*y) + (y^3)* cos(x).
# Differentiating with respect to y gives: x^2 + 3* (y^2)*sin(x)

# %% [markdown]
# ### Q5 Using JAX to confirm the gradient

# %%
import jax
import jax.numpy as jnp
import numpy as np

# Define the function using JAX-compatible numpy
def f(x, y):
    return x**2 * y + y**3 * jnp.sin(x)

# Define the gradient function using JAX
grad_fn = jax.grad(f, (0, 1))

# Generate random values for x and y
random_values = np.random.rand(5, 2)  # 5 samples, 2 variables

# Compute gradients using JAX
jax_gradients = np.array([grad_fn(x, y) for x, y in random_values])

# Display the results
for i in range(len(random_values)):
    x_val, y_val = random_values[i]
    grad_x, grad_y = jax_gradients[i]
    print(f"values: ({x_val}, {y_val}), Gradient: {grad_x}, {grad_y}")
# Out:
# values: (0.5567134148691611, 0.9374589958590913), Gradient: 1.7432515621185303, 1.7030467987060547
# values: (0.9232598063502504, 0.13407180234366212), Gradient: 0.24901995062828064, 0.8954183459281921
# values: (0.07182027297465632, 0.45142358360750934), Gradient: 0.15659815073013306, 0.04902772232890129
# values: (0.2455813791782211, 0.512653490862196), Gradient: 0.3824860751628876, 0.25199615955352783
# values: (0.8090922937692134, 0.24024997427583805), Gradient: 0.39833933115005493, 0.7799395322799683

# %% [markdown]
# ### Q6 Using Sympy to calculate the Derivatives and gradient

# %%
import sympy as sp
x, y = sp.symbols('x y')

f = x**2 * y + y**3 * sp.sin(x)
derivative_x = sp.diff(f, x)
derivative_y = sp.diff(f, y)

# %%
grad = np.array([derivative_x, derivative_y])
grad
# Out:
# array([2*x*y + y**3*cos(x), x**2 + 3*y**2*sin(x)], dtype=object)

# %%
values_for_x = random_values[:, 0]
values_for_y = random_values[:, 1]
#substituting x and y with the random values
derivative_x_values = [derivative_x.subs({x: x_val, y: y_val}) for x_val, y_val in zip(values_for_x, values_for_y)]
derivative_y_values = [derivative_y.subs({x: x_val, y: y_val}) for x_val, y_val in zip(values_for_x, values_for_y)]

# Display
for i in range(len(random_values)):
    x_val, y_val = values_for_x[i], values_for_y[i]
    deriv_x_val, deriv_y_val = derivative_x_values[i], derivative_y_values[i]
    print(f"values: ({x_val}, {y_val}), Derivatives: {deriv_x_val}, {deriv_y_val}")
# Out:
# values: (0.5567134148691611, 0.9374589958590913), Derivatives: 1.74325162304652, 1.70304686750328
# values: (0.9232598063502504, 0.13407180234366212), Derivatives: 0.249019965285387, 0.895418347208323
# values: (0.07182027297465632, 0.45142358360750934), Derivatives: 0.156598141992402, 0.0490277209107975
# values: (0.2455813791782211, 0.512653490862196), Derivatives: 0.382486124145669, 0.251996179970282
# values: (0.8090922937692134, 0.24024997427583805), Derivatives: 0.398339359104132, 0.779939589881929

# %% [markdown]
# ### Q7 Python Nested dictionary

# %%
student_records = {
    2022: {
        'Branch 1': {
           'Roll_1': {
                'Name': 'Shah Faisal Khan',
                'Marks': {
                    'Maths': 100,
                    'English': 70
        }}
    
        },
        'Branch 2': {
            'Roll_1': {
                'Name': 'Shah Faisal',
                'Marks': {
                    'Maths': 100,
                    'English': 70
        }}
    }},
    2023: {
        'Branch 1': {},
        'Branch 2': {},
    },
    2024: {
        'Branch 1': {},
        'Branch 2': {},
    },
    2025: {
        'Branch 1': {},
        'Branch 2': {},
    }
}

# %%
student_records[2022]['Branch 1']['Roll_1']
# Out:
# {'Name': 'Shah Faisal Khan', 'Marks': {'Maths': 100, 'English': 70}}

# %% [markdown]
# ### Question 9 Plotting Using Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

def func(x):
    return x

x_values = np.arange(0.5, 100.0, 0.5)
y_values = func(x_values)

plt.plot(x_values, y_values, label='y = x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of the function y = x')
plt.legend()
plt.show()

# %%
def func(x):
    return x**2

x_values = np.arange(0.5, 100.0, 0.5)
y_values = func(x_values)

plt.plot(x_values, y_values, label='y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of the function y = x^2')
plt.legend()
plt.show()

# %%
def func(x):
    return x**3 / 100

x_values = np.arange(0.5, 100.0, 0.5)
y_values = func(x_values)

plt.plot(x_values, y_values, label='y = x^3 / 100')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of the function y = x^3 / 100')
plt.legend()
plt.show()

# %%
def func(x):
    return np.sin(x)

x_values = np.arange(0.5, 100.0, 0.5)
y_values = func(x_values)

plt.plot(x_values, y_values, label='y = sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of the function y = sin(x)')
plt.legend()
plt.show()

# %%
def func(x):
    return np.sin(x) / x

x_values = np.arange(0.5, 100.0, 0.5)
y_values = func(x_values)

plt.plot(x_values, y_values, label='y = sin(x) / x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of the function y = sin(x) / x')
plt.legend()
plt.show()

# %%
def func(x):
    return np.log(x)

x_values = np.arange(0.5, 100.0, 0.5)
y_values = func(x_values)

plt.plot(x_values, y_values, label='y = log(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of the function y = log(x)')
plt.legend()
plt.show()

# %%
def func(x):
    return np.exp(x)

x_values = np.arange(0.5, 100.0, 0.5)
y_values = func(x_values)

plt.plot(x_values, y_values, label='y = e^x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of the function y = e^x')
plt.legend()
plt.show()

# %% [markdown]
# ### Q10 Matrix of size 20 X 5

# %%
import pandas as pd
matrix = np.random.uniform(1, 2, size=(20, 5))

df = pd.DataFrame(matrix, columns=['a', 'b', 'c', 'd', 'e'])

# Find the column with the highest standard deviation
max_std_col = df.std().idxmax()
# Find the row with the lowest mean
min_mean_row = df.mean(axis=1).idxmin()

print("DataFrame:")
print(df)

# Print the result
print("\nColumn with the highest standard deviation:", max_std_col)
print("Row with the lowest mean:", min_mean_row)
# Out:
# DataFrame:
#            a         b         c         d         e
# 0   1.983233  1.706944  1.737634  1.088335  1.467819
# 1   1.241254  1.098614  1.219025  1.539515  1.699102
# 2   1.418074  1.470057  1.723379  1.730478  1.030941
# 3   1.749156  1.157161  1.893186  1.934693  1.614734
# 4   1.253056  1.964427  1.411815  1.849514  1.017092
# 5   1.947802  1.183689  1.971375  1.444824  1.841780
# 6   1.383164  1.780652  1.934244  1.116995  1.913125
# 7   1.821601  1.139858  1.797367  1.550510  1.527827
# 8   1.559587  1.710526  1.713090  1.166079  1.475016
# 9   1.453298  1.013735  1.560272  1.277770  1.736395
# 10  1.901339  1.346874  1.087146  1.465837  1.580217
# 11  1.236874  1.405366  1.111114  1.218114  1.282699
# 12  1.924277  1.387030  1.552653  1.063018  1.359569
# 13  1.058726  1.113076  1.286989  1.587229  1.372857
# 14  1.017796  1.110724  1.796554  1.221459  1.757443
# 15  1.070945  1.080246  1.304100  1.085882  1.566125
# ...

# %% [markdown]
# ### Q11 Column 'f'

# %%
# Add a new column "f" 
df['f'] = df[['a', 'b', 'c', 'd', 'e']].sum(axis=1)

# Add a new column "g" 
df['g'] = np.where(df['f'] < 8, 'LT8', 'GT8')

# Find the number of rows where the value in the column "g" is "LT8"
num_lt8_rows = len(df[df['g'] == 'LT8'])

# Find the standard deviation of column "f" for the rows where "g" is "LT8" and "GT8"
std_dev_lt8 = df.loc[df['g'] == 'LT8', 'f'].std()
std_dev_gt8 = df.loc[df['g'] == 'GT8', 'f'].std()

print("Modified DataFrame:")
print(df)
print("\nNumber of rows where the value in column 'g' is 'LT8':", num_lt8_rows)
print("Standard deviation of column 'f' for rows where 'g' is 'LT8':", std_dev_lt8)
print("Standard deviation of column 'f' for rows where 'g' is 'GT8':", std_dev_gt8)
# Out:
# Modified DataFrame:
#            a         b         c         d         e         f    g
# 0   1.983233  1.706944  1.737634  1.088335  1.467819  7.983966  LT8
# 1   1.241254  1.098614  1.219025  1.539515  1.699102  6.797510  LT8
# 2   1.418074  1.470057  1.723379  1.730478  1.030941  7.372929  LT8
# 3   1.749156  1.157161  1.893186  1.934693  1.614734  8.348929  GT8
# 4   1.253056  1.964427  1.411815  1.849514  1.017092  7.495904  LT8
# 5   1.947802  1.183689  1.971375  1.444824  1.841780  8.389468  GT8
# 6   1.383164  1.780652  1.934244  1.116995  1.913125  8.128180  GT8
# 7   1.821601  1.139858  1.797367  1.550510  1.527827  7.837163  LT8
# 8   1.559587  1.710526  1.713090  1.166079  1.475016  7.624300  LT8
# 9   1.453298  1.013735  1.560272  1.277770  1.736395  7.041471  LT8
# 10  1.901339  1.346874  1.087146  1.465837  1.580217  7.381414  LT8
# 11  1.236874  1.405366  1.111114  1.218114  1.282699  6.254166  LT8
# ...

# %% [markdown]
# ### Q12 Broadcasting in Numpy

# %% [markdown]
# Broadcasting in numpy allows element wise operation on arrays even if their sizes and dimensions are different. it automatically aligns and extends the smaller array

# %%
arr1 = np.array([[1, 2, 3],
                 [4, 5, 6]])
arr2 = np.array([10, 20, 30])
result = arr1 + arr2

print("Array 1:")
print(arr1)
print("\nArray 2:")
print(arr2)
print("\nResult of broadcasting:")
print(result)
# Out:
# Array 1:
# [[1 2 3]
#  [4 5 6]]
#
# Array 2:
# [10 20 30]
#
# Result of broadcasting:
# [[11 22 33]
#  [14 25 36]]

# %% [markdown]
# ### Q13 Argmin of a numpy array

# %%
def custom_argmin(arr):
    if len(arr) == 0:
        raise ValueError("Input array is empty")
    min_value = arr[0]
    min_index = 0

    for i, value in enumerate(arr):
        if value < min_value:
            min_value = value
            min_index = i

    return min_index, min_value

# %%
arr = np.array([4, 1, 8, 3, 6,3524,-123])
custom_argmin_result, min_value = custom_argmin(arr)

np_argmin_result = np.argmin(arr)

print("Custom argmin result (index, value):", custom_argmin_result, min_value)
print("np.argmin result:", np_argmin_result)
# Out:
# Custom argmin result (index, value): 6 -123
# np.argmin result: 6
